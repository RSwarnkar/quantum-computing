# %% [markdown]
# Hi all, I am trying to extend the notion of Operator for biased dice. Say if we are given probability ratio of faces of a crooked dice as $F1:F2:F3:F4:F5:F6 = 1:2:3:4:5:6$ so how do I derive the Operator for a crooked dice? Could someone guide me because for coin its easy I want it more general case  just for my understanding.
#
# I mean its a 6 by 6 matrix with all element as 1/6  if a non-crooked dice but unable to figure out the transition for crooked.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# $$
# sober \ dice \ stochastic \ operator =
# \begin{bmatrix}
# \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} \\
# \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} \\
# \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} \\
# \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} \\
# \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} \\
# \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} \\
# \end{bmatrix}
# $$
#
# $$
# loaded \ dice \ stochastic \ operator =
# \begin{bmatrix}
# \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} & \frac{1}{21} \\
# \frac{2}{21} & \frac{2}{21} & \frac{2}{21} & \frac{2}{21} & \frac{2}{21} & \frac{2}{21} \\
# \frac{3}{21} & \frac{3}{21} & \frac{3}{21} & \frac{3}{21} & \frac{3}{21} & \frac{3}{21} \\
# \frac{4}{21} & \frac{4}{21} & \frac{4}{21} & \frac{4}{21} & \frac{4}{21} & \frac{4}{21} \\
# \frac{5}{21} & \frac{5}{21} & \frac{5}{21} & \frac{5}{21} & \frac{5}{21} & \frac{5}{21} \\
# \frac{6}{21} & \frac{6}{21} & \frac{6}{21} & \frac{6}{21} & \frac{6}{21} & \frac{6}{21} \\
# \end{bmatrix}
# $$

# %%
import numpy as np

A = np.array([
    #[1/10],[2/10],[2/10],[1/10],[2/10],[2/10]  
     [1/6],[1/6],[1/6],[1/6],[1/6],[1/6] 
])

B = np.matmul(A,np.transpose(A))

print(A)
print()
print(B)
# Out:
# [[0.16666667]
#  [0.16666667]
#  [0.16666667]
#  [0.16666667]
#  [0.16666667]
#  [0.16666667]]
#
# [[0.02777778 0.02777778 0.02777778 0.02777778 0.02777778 0.02777778]
#  [0.02777778 0.02777778 0.02777778 0.02777778 0.02777778 0.02777778]
#  [0.02777778 0.02777778 0.02777778 0.02777778 0.02777778 0.02777778]
#  [0.02777778 0.02777778 0.02777778 0.02777778 0.02777778 0.02777778]
#  [0.02777778 0.02777778 0.02777778 0.02777778 0.02777778 0.02777778]
#  [0.02777778 0.02777778 0.02777778 0.02777778 0.02777778 0.02777778]]

# %% [markdown]
# ## Loaded dice transition state:

# %% [markdown]
# Imagine a 3 face fair dice, and it is tossed *once* then transition diagram will look like:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now imagine a 3 face **loaded** dice, and it is tossed once then transition diagram will look like:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Imagine a three face loaded dice with bias ratio as $F1:F2:F3 = 5:3:2$.
#
# When this dice is tossed twice the transition diagram will look like.
#
#
# ![image.png](attachment:image.png)
