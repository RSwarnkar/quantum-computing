# %% [markdown]
# ## Quick Note about UGate `qc.u()` vs R-phi `qc.rz()`:
#
# * qc.u() is generic gate that can rotate the state along _ANY_ axis (roll,pitch,yaw).
# * qc.rz() is specific gate that rotates around the Z-axis only.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
