# %% [markdown]
# # General Unitary Gate $U$:
#
# [Qiskit UGate](https://qiskit.org/documentation/stubs/qiskit.circuit.library.UGate.html)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_bloch_multivector, plot_histogram, visualize_transition 
import math

# %%
num_qb = 1
qc = QuantumCircuit(num_qb)

which_qb = 0

theta = 3*math.pi/4
phi = -1 * math.pi/2
lmbda = math.pi/2

qc.u(theta,phi,lmbda, which_qb) ## NOTE THIS !!!!!!!!!!!!!
   

qc.draw("mpl")

# %%
backend = Aer.get_backend("statevector_simulator")
out = execute(qc,backend).result().get_statevector()
plot_bloch_multivector(out)

# %%
# visualize_transition(qc) # VisualizationError: 'Gate u is not supported'

# %%
plot_histogram(execute(qc,backend).result().get_counts())

# %% [markdown]
# # Identity Gate $I$:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Finding which is angle is for which axis:
# WE DON'T KNOW:
# * check [this reddit](https://www.reddit.com/r/Qiskit/comments/wez0f9/question_about_ugate/)
# * As per [this stack post](https://quantumcomputing.stackexchange.com/questions/11410/):
#
# ```
# UGate(theta, phi, lam, label=None)
#
# z-rotation (λ)
# y-rotation (θ)
# z-rotation (φ)
#
# ```
# * Even [doc](https://qiskit.org/documentation/stubs/qiskit.circuit.QuantumCircuit.u.html#qiskit.circuit.QuantumCircuit.u) does not has it.
#
# ![image.png](attachment:image.png)

# %%
num_qb = 1
qc = QuantumCircuit(num_qb)

which_qb = 0


theta =  0       # rotate by angle wrt. x-axis     
phi   =  0  # rotate by angle wrt. z-axis
lmbda =  math.pi  # rotate by angle wrt y-axiz

qc.u(theta,phi,lmbda, which_qb) ## NOTE THIS !!!!!!!!!!!!!
#qc.draw("mpl")

backend = Aer.get_backend("statevector_simulator")
out = execute(qc,backend).result().get_statevector()
# plot_bloch_multivector(out)

plot_histogram(execute(qc,backend).result().get_counts())
