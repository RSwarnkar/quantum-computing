# %%
from qiskit import QuantumCircuit, Aer, execute, QuantumRegister, assemble 
from qiskit.visualization import plot_histogram, plot_bloch_multivector, visualize_transition 
from qiskit_textbook.tools import array_to_latex
import math
import cmath

# %%
from qiskit.quantum_info import random_statevector, Statevector
from qiskit import QuantumCircuit
# import numpy as np

vec = random_statevector(2)
# vec = Statevector([1, 0])
print('before circuit: {}'.format(vec)) 

qc = QuantumCircuit(1)
qc.x(0)
qc.draw()

new_vec = vec.evolve(qc)
print('after circuit: {}'.format(new_vec))

from qiskit.visualization import plot_bloch_multivector, visualize_transition

#plot_bloch_multivector(qc)
#visualize_transition(qc)
# Out:
# before circuit: Statevector([-0.24671432-0.45376606j, -0.84195795+0.15599748j],
#             dims=(2,))
# after circuit: Statevector([-0.84195795+0.15599748j, -0.24671432-0.45376606j],
#             dims=(2,))

# %%
# https://www.youtube.com/watch?v=tOWV94-ydL4&ab_channel=Qiskit
 
from qiskit.quantum_info import random_statevector, Statevector
from qiskit import QuantumCircuit
from qiskit.visualization import plot_state_qsphere


#rand_state = random_statevector(4)  # 4 Complex aplitude for 2 Qubits 
rand_state = random_statevector(8)  # 8 Complex aplitude for 3 Qubits 
#rand_state = random_statevector(16)  # 8 Complex aplitude for 4 Qubits 
# ...
#rand_state = random_statevector(2^n)  # 8 Complex aplitude for n Qubits 

#rand_state = random_statevector(5) # VisualizationError: 'Input is not a multi-qubit quantum state.'

print(rand_state)
# Out:
# Statevector([ 0.05913347+0.23202886j, -0.17518453+0.44632687j,
#               0.03970067+0.04981137j,  0.23956375+0.03172829j,
#              -0.06390923+0.72742391j, -0.26885686+0.07226255j,
#               0.03770892+0.03703521j, -0.17534614+0.07770516j],
#             dims=(2, 2, 2))

# %%
plot_state_qsphere(rand_state)

# %%
rand_state.data
# Out:
# array([ 0.05913347+0.23202886j, -0.17518453+0.44632687j,
#         0.03970067+0.04981137j,  0.23956375+0.03172829j,
#        -0.06390923+0.72742391j, -0.26885686+0.07226255j,
#         0.03770892+0.03703521j, -0.17534614+0.07770516j])
