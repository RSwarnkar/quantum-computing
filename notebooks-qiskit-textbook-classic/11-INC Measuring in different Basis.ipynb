# %% [markdown]
# Use the below link to solve problem:
#
# https://qiskit.org/textbook/ch-states/single-qubit-gates.html#4.-Digression:-Measuring-in-Different-Bases--
#
# ![image.png](attachment:image.png)
