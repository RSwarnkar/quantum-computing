# %% [markdown]
# https://quantumcomputing.stackexchange.com/questions/27800/does-having-infinitely-many-quantum-gates-helpful-in-solving-problems-in-any-way

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
