# %% [markdown]
# ### Transpiling Quantum Circuit:
#
# What is Transpiling quantum circuit?
#
# https://www.youtube.com/watch?v=8mrPNSctRIg&ab_channel=Qiskit

# %% [markdown]
# Refer this youtube video and implement a transpile gate for given matrix:
#
# https://www.youtube.com/watch?v=O2WcZS4yO1Q&t=11s&ab_channel=Qiskit

# %% [markdown]
# ![image.png](attachment:image.png)
