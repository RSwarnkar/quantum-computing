# %% [markdown]
# ### Tensor Product:
#
# 1. Since we know that:
# $ (U_1 \vert q_0 \rangle) \otimes (U_2 \vert q_1 \rangle)   = ( U_1 \otimes U2 ) \ \vert q_0 q_1 \rangle $
#
# Here $U_1, U2$ could be any single qubit gates (e.g. $I,X,Y,Z,S,T,H, R_{Z(\phi)}, U_3, U_2, U_1 \ etc$) and $ U = ( U_1 \otimes U2 )$ is the Unitary matrix calculated above.
#
#
# 2. Hence Calculate product $\vert q_0 q_1 \rangle$. This is called as [Tensor product of ket vectors](https://physics.stackexchange.com/a/417681/330760).
#
#
# 3. Assume, qubits are initilized as zeros then this will be $\vert q_0 q_1 \rangle = \vert 0 \rangle \otimes \vert 0 \rangle = \vert 00 \rangle  $. As per $\S Thomas Wong 4.2.2$ this will be :
#
# $$ \vert 00 \rangle =
# \begin{bmatrix}
# 1 \\
# 0 \\
# 0 \\
# 0 \\
# \end{bmatrix}
# $$
#
#
# 4. Finally Multiply $U$ with $\vert 00 \rangle$ go get $ U \vert 00 \rangle$ by simple matrix multiplication.

# %% [markdown]
# ### By the way what's difference:
#
# * Inner Product (Scalar product): $ \langle \psi_1 \vert \psi_2 \rangle = \langle \psi_1 \vert \cdot \vert \psi_2 \rangle$
# * Outer product (Vector Product or Matrix Multiplication):  $ \vert \psi_1 \rangle \cdot \langle \psi_2 \vert $
# * Tensor Products of two kets (Kronecker Product): $\vert \psi_1 \rangle \otimes \vert \psi_2 \rangle = \vert \psi_1 \psi_2 \rangle$
# * Tensor Products of two bras (Kronecker Product): $\langle \psi_1 \vert \otimes \langle \psi_2 \vert = \langle \psi_1 \psi_2 \vert$
#
# Tensor product are special kind of product called Kronecker products and not plain Matrix Multiplication.
#
#
# Here is a good video:
# * [Eigen Chris - Tensor Product vs Kronecker Product](https://www.youtube.com/watch?v=qp_zg_TD0qE&ab_channel=eigenchris)
# * [PhysicsforStudents-Unleashyourpower](https://www.youtube.com/watch?v=kN2b_cx-zp0)
# * Also serach about Rank of Matrix and Order of Matrix in Math
# * Also search: Rank-0 Tensor is scalar, Rank-1 Tensor is a vector and Rank-2 Tensor is a Matrix beyonk Rank-3 all tesnors are called tesnors.

# %% [markdown]
# ## Exercise:
#
# 1. Given 2 vectors and a matrix:
#
# $$ A =
# \begin{bmatrix}
# a_1 & a_2 & a_3 \\
# \end{bmatrix} \\
# $$
#
# $$ B =
# \begin{bmatrix}
# b_1 \\
# b_2 \\
# \end{bmatrix}
# $$
#
#
#
# $$ C =
# \begin{bmatrix}
# c_1 & c_2 \\
# c_3 & c4 \\
# \end{bmatrix}
# $$
#
# Find below:
#
# - calculate: $A \otimes B \otimes C$.
# - Should you calculate the product from the left side or right side in the expression: $A \otimes B \otimes C$?
# - Is this associative?: $ (A \otimes B) \otimes C == A \otimes (B \otimes C)$

# %% [markdown]
# ## Some Note from Wolfram Alpa:
# * [Tensor Rank](https://mathworld.wolfram.com/TensorRank.html)
# ![image.png](attachment:image.png)
